# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL.Image 
import matplotlib.image as mpimg

# %%
img1 = mpimg.imread('Igroundtruth_82.bmp')
imgplot = plt.imshow(img1)
plt.show()

img2 = mpimg.imread('Igroundtruth_137.bmp')
imgplot = plt.imshow(img2)
plt.show()

img3 = mpimg.imread('Igroundtruth_147.bmp')
imgplot = plt.imshow(img3)
plt.show()

img4 = mpimg.imread('Igroundtruth_183.bmp')
imgplot = plt.imshow(img4)
plt.show()
