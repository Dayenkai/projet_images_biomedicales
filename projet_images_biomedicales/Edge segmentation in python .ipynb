# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np

# %%
img = cv2.imread('Igroundtruth_82.bmp')

# %%
plt.hist(img.ravel(),256,[0,256]); plt.show()
plt.imshow(img)
plt.show()

# %%
img_color = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
ret, thresh = cv2.threshold(gray, 100, 250, cv2.THRESH_BINARY)
ret1, thresh1 = cv2.threshold(gray, 200, 250, cv2.THRESH_TRUNC)

# %%
print(ret)
print(ret1)
# Out:
# 100.0
# 200.0

# %%
plt.imshow(thresh)
plt.show()
plt.imshow(thresh1)
plt.show()
